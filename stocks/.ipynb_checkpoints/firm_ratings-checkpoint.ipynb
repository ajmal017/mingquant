# %%
smallcap_tickers = pd.read_csv("small_cap_volume.csv")
smallcap_tickers.head()
# Out:
#   Symbol                       Name   Last  Change    %Chg   High   Low  \
# 0    HTZ  Hertz Global Holdings Inc   2.84   -0.23  -7.49%   3.04  2.80
# 1   SAVE        Spirit Airlines Inc  10.17    0.10   0.99%  10.47  9.86
# 2   BBBY          Bed Bath & Beyond   6.70   -0.10  -1.47%   7.13  6.57
# 3   KDMN        Kadmon Holdings Llc   4.66    0.11   2.42%   4.78  4.50
# 4   DVAX       Dynavax Technologies   5.13   -0.53  -9.36%   5.71  5.00
#
#        Volume     Time
# 0  25626701.0  5/22/20
# 1  17173000.0  5/22/20
# 2  12453100.0  5/22/20
# 3  11744300.0  5/22/20
# 4  11450400.0  5/22/20

# %%
#!/usr/pythonq
import pandas as pd
import os
import pandas_datareader.data as web
import pandas_datareader as pdr
from datetime import datetime
import matplotlib
import yfinance as yf
from datetime import timedelta
import numpy as np
yf.pdr_override()
ntickers = pd.read_csv("nasdaq_ticker_info.txt", sep="\t")
top_tickers = pd.read_csv("nasdaq_volume_leaders.csv")
midcap_tickers = pd.read_csv("mid_cap_volume_leaders.csv")
largecap_tickers = pd.read_csv("large_cap_volume_leaders.csv")
smallcap_tickers = pd.read_csv("small_cap_volume.csv")
# allsymbols = [i for i in set([x for x in largecap_tickers.Symbol] + [y for y in top_tickers.Symbol])]
allsymbols = [i for i in smallcap_tickers.Symbol]

def get_normalize_close(ticker, start, end):
    df = yf.download(ticker, auto_adjust = True, start = start, end = end)
    df[ticker] = df['Close']/df['Close'][0]
    return df[[ticker]]

def get_return(mdf, symbol, start, end):
    mdf = yf.download(symbol, start=start, end=end, progress=False)
    df = pd.DataFrame(mdf['Close'])
    dfout = df.loc[(df.index >= pd.to_datetime(start)) & (df.index <= pd.to_datetime(end))].dropna()
    returnval = (dfout['Close'][-1]-dfout['Close'][0])/dfout['Close'][0]
    return returnval

def add_days(date, ndays=5):
    return str(pd.to_datetime(date) + pd.tseries.offsets.BusinessDay(ndays)).split(" ")[0]


def get_combined_return(allreturns):
    return np.mean([np.mean(x) for x in [[i for i in j[1] if str(i) != 'nan'] for j in allreturns]])

def open_close_time(teststart):
    openstart, closestart = pd.to_datetime(str(teststart).split(" ")[0] + ' 13:30:00'), pd.to_datetime(str(teststart).split(" ")[0] + ' 20:00:00')
    if pd.to_datetime(teststart) > pd.to_datetime(openstart) and pd.to_datetime(teststart) < pd.to_datetime(closestart):
        return "midday"
    elif pd.to_datetime(teststart) > pd.to_datetime(closestart):
        return 'aftermarket'
    else:
        return 'premarket'

def next_date(date):
    return pd.to_datetime(date) + pd.tseries.offsets.BusinessDay(1)

def get_adj_date(release_type, date):
    if release_type == 'midday' or release_type == 'aftermarket':
        return next_date(date)
    else:
        return date
    
def get_up_ratings(symbol, start, end):
    dft = pd.DataFrame(index=pd.bdate_range(start, end))
    ticker = yf.Ticker(symbol)
    try:
        openstart = str(start) + ' 13:30:00'
        closestart = str(start) + ' 20:00:00'
        recs = ticker.recommendations
        recs.loc[(recs.index >= start) & (recs.index <= end)]
        recs['date'] = recs.copy().index.astype('str')
        recs['timing'] = recs.apply(lambda x: open_close_time(x['date']), axis=1)
        recs['adj_date'] = recs.apply(lambda x: get_adj_date(x['timing'], x['date']), axis=1)
        return [str(i).split(' ')[0] for i in recs[recs['Action'] == "up"].adj_date]
    except:
        return None

def get_ratings_returns(mdf, symbol, start, end, ndays):  
    up_days = get_up_ratings(symbol, start, end)
    returns = [get_return(mdf, symbol, day, add_days(day, ndays)) for day in up_days]
    print("stock: " + symbol + " return: " + str(np.mean(returns)) + " std: " + str(np.std(returns)))
    return returns
    
def get_returns_recs(mdf, symbols, startdate, enddate, ndays):
    allreturns = []
    for symbol in symbols:
        try:
            print("running for: " + str(symbol))
            returns = get_ratings_returns(mdf, symbol, startdate, enddate, ndays)
            allreturns.append([symbol, returns])
        except:
            print("failed for: " + str(symbol))
    return allreturns

# startdate = sys.argsv[1]
# enddate = sys.argsv[2]
# ndays = sys.argsv[3]

# %%
rated_stocks = []
startdate = '2019-01-01'
enddate = '2020-01-30'
symbols = allsymbols[:100]
for symbol in symbols:
    if get_up_ratings(symbol, startdate, enddate):
        rated_stocks.append(symbol)
mdf = yf.download(symbols, start=startdate, end=enddate)['Close']

symbols = rated_stocks

for ndays in [20, 30, 50, 100]:
    starttime = datetime.now()
    allreturns = get_returns_recs(mdf, symbols, startdate, enddate, ndays)
    combined_return = get_combined_return(allreturns)
    print("combined return for " + str(ndays) + " day hold: " + str(combined_return))
    print("all return length: " + str(len(allreturns)))
    outdf = pd.DataFrame.from_dict({'symbol': [i[0] for i in allreturns], 'returns': [i[1] for i in allreturns]}, orient='columns')
    outdf.to_csv("out_allreturns_smallcap_" + str(ndays) + "days_first100_2019-01-01_2_2019-04-03_may25.txt", sep="\t")
    endtime = datetime.now()
    print("this took: " + str(endtime-starttime) + " for " + str(ndays) + " days!")
    
rated_stocks = []
startdate = '2019-01-01'
enddate = '2019-04-30'
symbols = allsymbols[101:200]
for symbol in symbols:
    if get_up_ratings(symbol, startdate, enddate):
        rated_stocks.append(symbol)
mdf = yf.download(symbols, start=startdate, end=enddate)['Close']

symbols = rated_stocks

for ndays in [20, 30, 50, 100]:
    starttime = datetime.now()
    allreturns = get_returns_recs(mdf, symbols, startdate, enddate, ndays)
    combined_return = get_combined_return(allreturns)
    print("combined return for " + str(ndays) + " day hold: " + str(combined_return))
    print("all return length: " + str(len(allreturns)))
    outdf = pd.DataFrame.from_dict({'symbol': [i[0] for i in allreturns], 'returns': [i[1] for i in allreturns]}, orient='columns')
    outdf.to_csv("out_allreturns_smallcap_" + str(ndays) + "days_100to200stocks_2019-01-01_2_2019-04-03_may25.txt", sep="\t")
    endtime = datetime.now()
    print("this took: " + str(endtime-starttime) + " for " + str(ndays) + " days!")

rated_stocks = []
startdate = '2019-01-01'
enddate = '2019-04-30'
symbols = allsymbols[201:300]
for symbol in symbols:
    if get_up_ratings(symbol, startdate, enddate):
        rated_stocks.append(symbol)
mdf = yf.download(symbols, start=startdate, end=enddate)['Close']

symbols = rated_stocks

for ndays in [20, 30, 50, 100]:
    starttime = datetime.now()
    allreturns = get_returns_recs(mdf, symbols, startdate, enddate, ndays)
    combined_return = get_combined_return(allreturns)
    print("combined return for " + str(ndays) + " day hold: " + str(combined_return))
    print("all return length: " + str(len(allreturns)))
    outdf = pd.DataFrame.from_dict({'symbol': [i[0] for i in allreturns], 'returns': [i[1] for i in allreturns]}, orient='columns')
    outdf.to_csv("out_allreturns_smallcap_" + str(ndays) + "days_200to300stocks_2019-01-01_2_2019-04-03_may25.txt", sep="\t")
    endtime = datetime.now()
    print("this took: " + str(endtime-starttime) + " for " + str(ndays) + " days!")
# Out:
# [*********************100%***********************]  100 of 100 completed
#
# 1 Failed download:
# - GAN: Data doesn't exist for startDate = 1546329600, endDate = 1580371200
# running for: SAVE
# stock: SAVE return: -0.00780574436398953 std: 0.07737823909849947
# running for: BBBY
# stock: BBBY return: 0.017859759455806753 std: 0.12074184663226732
# running for: KDMN
# stock: KDMN return: -0.014285700905079517 std: 0.0
# running for: CLVS
# stock: CLVS return: 0.026477298582897702 std: 0.10387414901370717
# running for: INSG
# stock: INSG return: 0.05434783805858864 std: 0.0
# running for: IVR
# stock: IVR return: 0.008175353455407399 std: 0.048783478163430455
# running for: ATRA
# stock: ATRA return: 0.5257693907791129 std: 0.5359314504633725
# running for: AR
# stock: AR return: -0.027337391955430158 std: 0.09780533557182573
# running for: NAT
# stock: NAT return: -0.03917630380424263 std: 0.0498250472238621
# running for: RWT
# stock: RWT return: 0.004058085323037648 std: 0.08005843555260819
# running for: HOME
#
# 1 Failed download:
# - HOME: Data doesn't exist for startDate = 1382684400, endDate = 1385107200
# failed for: HOME
# running for: WTI
# stock: WTI return: -0.02608042028191562 std: 0.18335118840238296
# running for: MTDR
# stock: MTDR return: 0.0017483235890513693 std: 0.10128931936474597
# running for: SM
# stock: SM return: -0.05035626814184669 std: 0.15929652259674099
# running for: BCRX
# stock: BCRX return: 0.13285061058129682 std: 0.3702293049378333
# running for: OCUL
# stock: OCUL return: -0.08445724936819406 std: 0.11228988060260799
# running for: BKD
# stock: BKD return: 7.624253637590581e-05 std: 0.037266628113402596
# running for: TSE
# stock: TSE return: -0.15745459863626488 std: 0.1455131033311125
# running for: FSM
# stock: FSM return: -0.07487778381662391 std: 0.10977633379805904
# running for: ELF
# stock: ELF return: 0.08437016682307141 std: 0.11854807975444268
# running for: MNK
# stock: MNK return: 0.03588297509646678 std: 0.17039777925377095
# running for: CODX
# failed for: CODX
# running for: BGCP
# stock: BGCP return: -0.010029740857553492 std: 0.08541376688901405
# running for: BLMN
# stock: BLMN return: -0.016189451931863816 std: 0.07468227452693331
# running for: AXL
# stock: AXL return: 0.05701271932700235 std: 0.12350406351795556
# running for: MIK
# stock: MIK return: -0.0021571189286416705 std: 0.07284453546283175
# running for: AMC
# stock: AMC return: -0.008851619998827557 std: 0.1691779852254066
# running for: ENDP
# stock: ENDP return: 0.07387060180196343 std: 0.1156499393380634
# running for: ANF
# stock: ANF return: 0.016799473313530978 std: 0.11438196491974385
# running for: ADMA
# stock: ADMA return: -0.1568627542644592 std: 0.0
# running for: CERS
# stock: CERS return: -0.10904873198376984 std: 0.0
# running for: RUBI
# stock: RUBI return: -0.04212260280227394 std: 0.13712263141250342
# running for: OSTK
# stock: OSTK return: 0.12424480834728015 std: 0.2211903960750804
# running for: CRK
# stock: CRK return: 0.09000123475816885 std: 0.25738171607002736
# running for: GBX
# stock: GBX return: 0.008770615819253183 std: 0.049827860835517074
# running for: EROS
# stock: EROS return: -0.2196721561619493 std: 0.0
# running for: EVRI
# stock: EVRI return: 0.4044663902588918 std: 0.0
# running for: SKT
# stock: SKT return: 0.025085212939650218 std: 0.06550828544733193
# running for: GIII
# stock: GIII return: 0.030952918826541775 std: 0.09821894587610848
# running for: BBAR
# stock: BBAR return: 0.060834903878942664 std: 0.11558158587549344
# running for: APY
# stock: APY return: 0.051985245516671205 std: 0.032672467026780436
# running for: FLDM
# stock: FLDM return: -0.05723473291871165 std: 0.17999940643597145
# running for: INFN
# stock: INFN return: -0.03302254619889056 std: 0.15258261636543696
# running for: JKS
# stock: JKS return: 0.09780794713303549 std: 0.13961744081018085
# running for: TNP
# stock: TNP return: -0.007129461173831981 std: 0.1318785021762375
# running for: ABR
# stock: ABR return: -0.029624969101497516 std: 0.05514328615075312
# running for: GPRO
# stock: GPRO return: 0.014388093643556176 std: 0.10387798223916511
# running for: IMGN
# stock: IMGN return: -0.13677288148049765 std: 0.17035704449947603
# running for: RLGY
# stock: RLGY return: -0.09206867119503309 std: 0.18400433142260197
# running for: TGI
# stock: TGI return: 0.0320850001767935 std: 0.1824136911657335
# running for: CAKE
# stock: CAKE return: -0.009511319694942974 std: 0.15772234524716058
# running for: BTU
#
# 1 Failed download:
# - BTU: Data doesn't exist for startDate = 1338274800, endDate = 1340694000
# failed for: BTU
# running for: PBI
# stock: PBI return: -0.032812521523724804 std: 0.03028527344922963
# running for: VET
# stock: VET return: -0.06240306145999747 std: 0.009065730045227934
# running for: CADE
# stock: CADE return: -0.07361562234207444 std: 0.03794896584793382
# running for: FLXN
# stock: FLXN return: -0.006060662107580571 std: 0.0
# running for: DHC
# stock: DHC return: -0.04149370217269001 std: 0.09541490791187927
# running for: PUMP
# stock: PUMP return: -0.027696061737291187 std: 0.1769145873547343
# combined return for 20 day hold: 0.00588562470386737
# all return length: 55
# this took: 0:03:38.397600 for 20 days!
# running for: SAVE
# stock: SAVE return: -0.0012329448443117602 std: 0.10686086175556882
# running for: BBBY
# stock: BBBY return: 0.004598556397692926 std: 0.12381203229267025
# running for: KDMN
# stock: KDMN return: 0.021428551357619275 std: 0.0
# running for: CLVS
# stock: CLVS return: 0.07715113865033708 std: 0.26911255962654135
# running for: INSG
# stock: INSG return: 0.035326052626106094 std: 0.0
# running for: IVR
# stock: IVR return: -0.012465652788476 std: 0.04445985538123114
# running for: ATRA
# stock: ATRA return: 0.7213602829827496 std: 0.7913244034355156
# running for: AR
# stock: AR return: -0.033588618322484574 std: 0.08263194935776007
# running for: NAT
# stock: NAT return: -0.06747511483354963 std: 0.021238642589503684
# running for: RWT
# stock: RWT return: 0.018742017186901837 std: 0.06322638613029032
# running for: HOME
#
# 1 Failed download:
# - HOME: Data doesn't exist for startDate = 1382684400, endDate = 1386316800
# failed for: HOME
# running for: WTI
# stock: WTI return: 0.004666807458596053 std: 0.2712108946562253
# running for: MTDR
# stock: MTDR return: -0.005799560048032777 std: 0.1596058292050172
# running for: SM
# stock: SM return: -0.04324526999301878 std: 0.21519678675814266
# running for: BCRX
# stock: BCRX return: 0.16410592132970228 std: 0.5247374936961224
# running for: OCUL
# stock: OCUL return: 0.04893949887146959 std: 0.08981493811546369
# running for: BKD
# stock: BKD return: 0.011066986811743219 std: 0.04960316700103501
# running for: TSE
# stock: TSE return: -0.16863106322603283 std: 0.22489256653192918
# running for: FSM
# stock: FSM return: -0.08764428738916769 std: 0.08623642003907385
# running for: ELF
# stock: ELF return: -0.004930865752556628 std: 0.24115192888640008
# running for: MNK
# stock: MNK return: 0.012395471555359583 std: 0.23306095734620993
# running for: CODX
# stock: CODX return: -0.0016146763599945017 std: 0.0
# running for: BGCP
# stock: BGCP return: 0.024554096759374668 std: 0.07184569275122486
# running for: BLMN
# stock: BLMN return: -0.006410659817399571 std: 0.07448386876763474
# running for: AXL
# stock: AXL return: 0.034859801298639616 std: 0.18999859869702607
# running for: MIK
# stock: MIK return: 0.011244371726399496 std: 0.13495208899036681
# running for: AMC
# stock: AMC return: 0.006537150285448795 std: 0.22067488355106735
# running for: ENDP
# stock: ENDP return: 0.05745186993266239 std: 0.17023419159165085
# running for: ANF
# stock: ANF return: 0.018085233014235265 std: 0.13717277223542138
# running for: ADMA
# stock: ADMA return: -0.04248362040956573 std: 0.0
# running for: CERS
# stock: CERS return: 0.006960605616389479 std: 0.0
# running for: RUBI
# stock: RUBI return: -0.046698070518821994 std: 0.1466980943606799
# running for: OSTK
# stock: OSTK return: 0.18477969094274074 std: 0.15157916107979222
# running for: CRK
# stock: CRK return: 0.07657421579709658 std: 0.2803342048474863
# running for: GBX
# stock: GBX return: 0.020690276254884128 std: 0.05699701534303682
# running for: EROS
# stock: EROS return: -0.2557376799036245 std: 0.0
# running for: EVRI
# stock: EVRI return: 0.5434241852030693 std: 0.0
# running for: SKT
# stock: SKT return: 0.04503218868502331 std: 0.07190370742065576
# running for: GIII
# stock: GIII return: 0.039821807847358545 std: 0.11197050381183016
# running for: BBAR
# stock: BBAR return: 0.03802013410356877 std: 0.14576622456654792
# running for: APY
# stock: APY return: 0.18275023970424933 std: 0.10850888082618945
# running for: FLDM
# stock: FLDM return: -0.04796892843422704 std: 0.21138269475438665
# running for: INFN
# stock: INFN return: -0.0014323454432723618 std: 0.15800837835240855
# running for: JKS
# stock: JKS return: 0.13991108236991176 std: 0.17756399528369343
# running for: TNP
# stock: TNP return: 0.030792850431962233 std: 0.21607030578989525
# running for: ABR
# stock: ABR return: -0.11727823682225799 std: 0.15954296844773352
# running for: GPRO
# stock: GPRO return: 0.019359062253640605 std: 0.18268927671015076
# running for: IMGN
# stock: IMGN return: -0.1101686096725883 std: 0.14753159047330824
# running for: RLGY
# stock: RLGY return: -0.10749418775423421 std: 0.16540554514385683
# running for: TGI
# stock: TGI return: 0.008924584097654408 std: 0.18277109850561765
# running for: CAKE
# stock: CAKE return: -0.004910002199365973 std: 0.1511110177096281
# running for: BTU
#
# 1 Failed download:
# - BTU: Data doesn't exist for startDate = 1338274800, endDate = 1341903600
# failed for: BTU
# running for: PBI
# stock: PBI return: -0.00845491307050387 std: 0.01695708023197497
# running for: VET
# stock: VET return: -0.035401993436565284 std: 0.05238648901164167
# running for: CADE
# stock: CADE return: -0.12653854318638272 std: 0.06620522765496997
# running for: FLXN
# stock: FLXN return: 0.016450179848110646 std: 0.0
# running for: DHC
# stock: DHC return: -0.03417575452259402 std: 0.12401485075687009
# running for: PUMP
# stock: PUMP return: 0.06187711666295725 std: 0.19756850127720404
# combined return for 30 day hold: 0.023501793380618325
# all return length: 56
# this took: 0:03:39.785419 for 30 days!
# running for: SAVE
# stock: SAVE return: -0.031972881318554025 std: 0.19629489752310983
# running for: BBBY
# stock: BBBY return: 0.02132667696176046 std: 0.23414483486214913
# running for: KDMN
# stock: KDMN return: -0.1642857307074024 std: 0.0
# running for: CLVS
# stock: CLVS return: 0.012953349593444779 std: 0.26008847364992616
# running for: INSG
# stock: INSG return: 0.027173886635466226 std: 0.0
# running for: IVR
# stock: IVR return: -0.007929909369390755 std: 0.07602270637279215
# running for: ATRA
# stock: ATRA return: 0.5403806402413219 std: 0.7372258634667709
# running for: AR
# stock: AR return: -0.048386040492876606 std: 0.13041347775096127
# running for: NAT
# stock: NAT return: 0.06021614157639495 std: 0.11620329620562272
# running for: RWT
# stock: RWT return: 0.0508420196520739 std: 0.07647000942526558
# running for: HOME
#
# 1 Failed download:
# - HOME: Data doesn't exist for startDate = 1382684400, endDate = 1388736000
# failed for: HOME
# running for: WTI
# stock: WTI return: 0.07470673237839451 std: 0.5142723381556726
# running for: MTDR
# stock: MTDR return: -0.011223425482466683 std: 0.18017644932299698
# running for: SM
# stock: SM return: -0.011389485667811209 std: 0.3267532276461522
# running for: BCRX
# stock: BCRX return: 0.24965276437802023 std: 0.6152048338525163
# running for: OCUL
# stock: OCUL return: 0.3127540630805272 std: 0.2209086979398896
# running for: BKD
# stock: BKD return: -0.009294695630626622 std: 0.12784048765739156
# running for: TSE
# stock: TSE return: -0.1915817370604452 std: 0.14477667586484855
# running for: FSM
# stock: FSM return: -0.052166960019241836 std: 0.05781105324371967
# running for: ELF
# stock: ELF return: 0.01692773376676704 std: 0.28860295217818116
# running for: MNK
# stock: MNK return: 0.024935034306835878 std: 0.17773419960123304
# running for: CODX
# stock: CODX return: -0.0016146763599945017 std: 0.0
# running for: BGCP
# stock: BGCP return: 0.048723196769862684 std: 0.042468310427791194
# running for: BLMN
# stock: BLMN return: 0.01842028754287213 std: 0.10222551638597524
# running for: AXL
# stock: AXL return: 0.05069435024750746 std: 0.26456718697829407
# running for: MIK
# stock: MIK return: -0.01632436671525238 std: 0.16964032783884367
# running for: AMC
# stock: AMC return: -0.0025934741947957266 std: 0.2553272972926807
# running for: ENDP
# stock: ENDP return: 0.060046221959472075 std: 0.278120064122545
# running for: ANF
# stock: ANF return: 0.05260453436783675 std: 0.18030469506850222
# running for: ADMA
# stock: ADMA return: 0.1993464525885947 std: 0.0
# running for: CERS
# stock: CERS return: 0.03944317367770344 std: 0.0
# running for: RUBI
# stock: RUBI return: -0.014056592341543828 std: 0.1840565494261996
# running for: OSTK
# stock: OSTK return: 0.2628662785705394 std: 0.2309938509580899
# running for: CRK
# stock: CRK return: -0.01635732394877378 std: 0.19301416617008338
# running for: GBX
# stock: GBX return: 0.03370022457963944 std: 0.07276942503800124
# running for: EROS
# stock: EROS return: -0.18032786885245902 std: 0.0
# running for: EVRI
# stock: EVRI return: 0.7220842917897756 std: 0.0
# running for: SKT
# stock: SKT return: 0.05678310505163863 std: 0.0839523850351016
# running for: GIII
# stock: GIII return: -0.0339296667376434 std: 0.19290493239409484
# running for: BBAR
# stock: BBAR return: -0.10157303864793209 std: 0.131973857744824
# running for: APY
# stock: APY return: 0.07368977973523638 std: 0.20687256631282136
# running for: FLDM
# stock: FLDM return: 0.052017768989371424 std: 0.26734908907949784
# running for: INFN
# stock: INFN return: -0.02010233340914854 std: 0.2117345897686527
# running for: JKS
# stock: JKS return: 0.10082041223154692 std: 0.33820717312711607
# running for: TNP
# stock: TNP return: 0.042560540812031894 std: 0.22656408828003768
# running for: ABR
# stock: ABR return: -0.27773799808716565 std: 0.36067260454783007
# running for: GPRO
# stock: GPRO return: -0.02541049022078022 std: 0.2656529737127734
# running for: IMGN
# stock: IMGN return: 0.09640149338988382 std: 0.29965519305333627
# running for: RLGY
# stock: RLGY return: -0.08286318640587208 std: 0.16473090795473583
# running for: TGI
# stock: TGI return: 0.09112515981181626 std: 0.26051175095701845
# running for: CAKE
# failed for: CAKE
# running for: BTU
# failed for: BTU
# running for: PBI
# failed for: PBI
# running for: VET
# failed for: VET
# running for: CADE
# stock: CADE return: -0.10745464460312586 std: 0.0657879779364592
# running for: FLXN
# failed for: FLXN
# running for: DHC
# stock: DHC return: -0.14182580174156847 std: 0.26567862356503325
# running for: PUMP
# stock: PUMP return: 0.09737942699325927 std: 0.4700098540865695
# combined return for 50 day hold: 0.037311027185860074
# all return length: 52
# this took: 0:03:34.940685 for 50 days!
# running for: SAVE
# failed for: SAVE
# running for: BBBY
# stock: BBBY return: -0.09346296619816463 std: 0.32477062764528186
# running for: KDMN
